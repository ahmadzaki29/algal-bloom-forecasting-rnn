# %%
# Import Library
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
# Parsing tanggal
def parse_date(date_str):
    return pd.to_datetime(date_str, infer_datetime_format=True)

# %%
# Memuat dataset dan mengonversi kolom tanggal
data = pd.read_csv('daily_mean.csv')

# %%
# Menghapus nilai nan
data.dropna()
# Out:
# Empty DataFrame
# Columns: [Lake, Date, Unnamed: 0, Unnamed: 0.1, lat, long, chla, secchi, TP, DOC, pH, TKN, NO2, NO3, NH4, Depth, DIC, Ost, Nord, temp, PAR, Depth_to, POC, SRP, TDN, NOx, TN, Year, Month, Day, day_of_year, num_samples]
# Index: []
#
# [0 rows x 32 columns]

# %%
# menunjukkan keberadaan nilai nan
data.isnull()
# Out:
#         Lake   Date  Unnamed: 0  Unnamed: 0.1   lat  long   chla  secchi  \
# 0      False  False       False          True  True  True  False    True
# 1      False  False       False          True  True  True  False    True
# 2      False  False       False          True  True  True  False    True
# 3      False  False       False          True  True  True  False    True
# 4      False  False       False          True  True  True  False    True
# ...      ...    ...         ...           ...   ...   ...    ...     ...
# 52111  False  False       False          True  True  True  False    True
# 52112  False  False       False          True  True  True  False    True
# 52113  False  False       False          True  True  True  False    True
# 52114  False  False       False          True  True  True  False    True
# 52115  False  False       False          True  True  True  False    True
#
#          TP   DOC  ...   POC   SRP   TDN   NOx    TN   Year  Month    Day  \
# 0      True  True  ...  True  True  True  True  True  False  False  False
# 1      True  True  ...  True  True  True  True  True  False  False  False
# 2      True  True  ...  True  True  True  True  True  False  False  False
# 3      True  True  ...  True  True  True  True  True  False  False  False
# 4      True  True  ...  True  True  True  True  True  False  False  False
# ...     ...   ...  ...   ...   ...   ...   ...   ...    ...    ...    ...
# 52111  True  True  ...  True  True  True  True  True  False  False  False
# 52112  True  True  ...  True  True  True  True  True  False  False  False
# 52113  True  True  ...  True  True  True  True  True  False  False  False
# 52114  True  True  ...  True  True  True  True  True  False  False  False
# 52115  True  True  ...  True  True  True  True  True  False  False  False
#
#        day_of_year  num_samples
# 0            False        False
# 1            False        False
# 2            False        False
# 3            False        False
# 4            False        False
# ...            ...          ...
# 52111        False        False
# 52112        False        False
# 52113        False        False
# 52114        False        False
# 52115        False        False
#
# [52116 rows x 32 columns]

# %%
# mengonversi kolom tanggal
data['Date'] = data['Date'].apply(parse_date)
# Out:
# <ipython-input-2-351a4f5dbc0a>:3: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   return pd.to_datetime(date_str, infer_datetime_format=True)

# %%
#  Menampilkan kolom Date dan chla
print(data[['Date', 'chla']])
# Out:
#             Date  chla
# 0     2001-04-17   4.2
# 1     2001-05-14   9.5
# 2     2001-06-14  17.5
# 3     2001-07-16  22.6
# 4     2001-08-16   6.9
# ...          ...   ...
# 52111 2019-06-18   3.2
# 52112 2019-07-15   7.0
# 52113 2019-08-15   4.9
# 52114 2019-09-11   6.4
# 52115 2019-10-14   2.3
#
# [52116 rows x 2 columns]

# %%
# Mengurutkan data berdasarkan kolom Date
data = data.sort_values('Date')

# %%
# Mengambil tanggal saja dari Date
data['Date'] = data['Date'].dt.date

# %%
# Mengelompokkan data berdasarkan Date dan menghitung rata-rata chla
daily_avg = data.groupby('Date')['chla'].mean().reset_index()

# %%
# Mengonversi kolom Date ke format datetime
daily_avg['Date'] = pd.to_datetime(daily_avg['Date'])

# %%
# Memisahkan data menjadi training (2001-2017) dan testing (2018-2019)
train_data = daily_avg[(daily_avg['Date'].dt.year >= 2001) & (daily_avg['Date'].dt.year <= 2017)]
test_data = daily_avg[(daily_avg['Date'].dt.year >= 2018) & (daily_avg['Date'].dt.year <= 2019)]

print("Training Data:")
print(train_data)

print("\nTesting Data:")
print(test_data)
# Out:
# Training Data:
#             Date       chla
# 5735  2001-01-01  17.835000
# 5736  2001-01-08   6.400000
# 5737  2001-01-09   6.192222
# 5738  2001-01-10  25.442857
# 5739  2001-01-15  31.600000
# ...          ...        ...
# 10079 2017-12-15   8.985714
# 10080 2017-12-18   7.600000
# 10081 2017-12-19   5.370000
# 10082 2017-12-28  44.350000
# 10083 2017-12-29   3.100000
#
# [4349 rows x 2 columns]
#
# Testing Data:
#             Date        chla
# 10084 2018-01-01  159.751140
# 10085 2018-01-02   38.800000
# 10086 2018-01-03   14.325000
# 10087 2018-01-04   18.133333
# 10088 2018-01-05   63.490000
# ...          ...         ...
# 10589 2019-12-16    2.360000
# 10590 2019-12-17    2.050000
# 10591 2019-12-18   10.730000
# 10592 2019-12-19    3.500000
# 10593 2019-12-23    3.300000
#
# [510 rows x 2 columns]

# %%
# Membuat grafik perubahan chla dari waktu ke waktu
plt.figure(figsize=(14, 5))
plt.plot(train_data['Date'], train_data['chla'], label='Training Data', marker='o', linestyle='-', color='b')
plt.plot(test_data['Date'], test_data['chla'], label='Testing Data', marker='o', linestyle='-', color='r')
plt.title('Perubahan chla dari Waktu ke Waktu')
plt.xlabel('Tanggal')
plt.ylabel('chla')
plt.grid(True)
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Menghitung Moving Average untuk data training dan testing
window_size = 7
train_data['MOVING_AVG'] = train_data['chla'].rolling(window=window_size).mean()
test_data['MOVING_AVG'] = test_data['chla'].rolling(window=window_size).mean()
# Out:
# <ipython-input-14-ddb316f45f03>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['MOVING_AVG'] = train_data['chla'].rolling(window=window_size).mean()
# <ipython-input-14-ddb316f45f03>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['MOVING_AVG'] = test_data['chla'].rolling(window=window_size).mean()

# %%
# Menghapus nilai NaN yang mungkin ada setelah menghitung Moving Average
train_data = train_data.dropna()
test_data = test_data.dropna()

# %%
# Menampilkan grafik Moving Average
plt.figure(figsize=(14, 5))
plt.plot(train_data['Date'], train_data['chla'], label='Training Data')
plt.plot(train_data['Date'], train_data['MOVING_AVG'], label='Training Moving Average', color='orange')
plt.plot(test_data['Date'], test_data['chla'], label='Testing Data')
plt.plot(test_data['Date'], test_data['MOVING_AVG'], label='Testing Moving Average', color='red')
plt.title('chla dengan Moving Average')
plt.xlabel('Tanggal')
plt.ylabel('chla')
plt.legend()
plt.show()

# %%
# Normalisasi data
scaler = MinMaxScaler(feature_range=(0, 1))
train_scaled = scaler.fit_transform(train_data[['MOVING_AVG']])
test_scaled = scaler.transform(test_data[['MOVING_AVG']])

# %%
# Fungsi untuk membuat sequences
def create_sequences(data, seq_length):
    sequences = []
    labels = []
    for i in range(len(data) - seq_length):
        sequences.append(data[i:i+seq_length])
        labels.append(data[i+seq_length])
    return np.array(sequences), np.array(labels)

# %%
# Menentukan panjang sequence
seq_length = 30
X_train, y_train = create_sequences(train_scaled, seq_length)
X_test, y_test = create_sequences(test_scaled, seq_length)

# %%
# Membangun model GRU
model = Sequential()
model.add(GRU(50, return_sequences=True, input_shape=(seq_length, 1)))
model.add(Dropout(0.2))
model.add(GRU(50))
model.add(Dropout(0.2))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
# Callback untuk early stopping
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# %%
# Melatih model
history = model.fit(X_train, y_train, epochs=60, batch_size=32, validation_data=(X_test, y_test), callbacks=[early_stop])
# Out:
# Epoch 1/60
# 135/135 [==============================] - 10s 37ms/step - loss: 0.0100 - val_loss: 0.0112
# Epoch 2/60
# 135/135 [==============================] - 5s 34ms/step - loss: 0.0058 - val_loss: 0.0091
# Epoch 3/60
# 135/135 [==============================] - 5s 38ms/step - loss: 0.0052 - val_loss: 0.0094
# Epoch 4/60
# 135/135 [==============================] - 4s 30ms/step - loss: 0.0051 - val_loss: 0.0082
# Epoch 5/60
# 135/135 [==============================] - 4s 32ms/step - loss: 0.0049 - val_loss: 0.0081
# Epoch 6/60
# 135/135 [==============================] - 5s 38ms/step - loss: 0.0047 - val_loss: 0.0083
# Epoch 7/60
# 135/135 [==============================] - 4s 30ms/step - loss: 0.0049 - val_loss: 0.0083
# Epoch 8/60
# 135/135 [==============================] - 4s 33ms/step - loss: 0.0046 - val_loss: 0.0094
# Epoch 9/60
# 135/135 [==============================] - 5s 36ms/step - loss: 0.0046 - val_loss: 0.0080
# Epoch 10/60
# 135/135 [==============================] - 4s 30ms/step - loss: 0.0046 - val_loss: 0.0078
# Epoch 11/60
# 135/135 [==============================] - 5s 35ms/step - loss: 0.0045 - val_loss: 0.0078
# Epoch 12/60
# 135/135 [==============================] - 5s 36ms/step - loss: 0.0046 - val_loss: 0.0079
# Epoch 13/60
# 135/135 [==============================] - 4s 30ms/step - loss: 0.0044 - val_loss: 0.0081
# Epoch 14/60
# 135/135 [==============================] - 5s 40ms/step - loss: 0.0043 - val_loss: 0.0078
# Epoch 15/60
# 135/135 [==============================] - 4s 33ms/step - loss: 0.0044 - val_loss: 0.0082
# Epoch 16/60
# 135/135 [==============================] - 4s 30ms/step - loss: 0.0043 - val_loss: 0.0084
# Epoch 17/60
# 135/135 [==============================] - 5s 37ms/step - loss: 0.0042 - val_loss: 0.0077
# Epoch 18/60
# 135/135 [==============================] - 4s 33ms/step - loss: 0.0041 - val_loss: 0.0075
# Epoch 19/60
# 135/135 [==============================] - 4s 30ms/step - loss: 0.0042 - val_loss: 0.0079
# Epoch 20/60
# 135/135 [==============================] - 5s 37ms/step - loss: 0.0040 - val_loss: 0.0068
# Epoch 21/60
# 135/135 [==============================] - 4s 32ms/step - loss: 0.0039 - val_loss: 0.0067
# Epoch 22/60
# 135/135 [==============================] - 4s 29ms/step - loss: 0.0038 - val_loss: 0.0067
# Epoch 23/60
# 135/135 [==============================] - 5s 37ms/step - loss: 0.0037 - val_loss: 0.0067
# Epoch 24/60
# 135/135 [==============================] - 4s 31ms/step - loss: 0.0037 - val_loss: 0.0067
# Epoch 25/60
# 135/135 [==============================] - 6s 46ms/step - loss: 0.0038 - val_loss: 0.0067
# Epoch 26/60
# 135/135 [==============================] - 6s 41ms/step - loss: 0.0037 - val_loss: 0.0070
# Epoch 27/60
# 135/135 [==============================] - 4s 31ms/step - loss: 0.0036 - val_loss: 0.0065
# Epoch 28/60
# 135/135 [==============================] - 4s 30ms/step - loss: 0.0036 - val_loss: 0.0065
# Epoch 29/60
# 135/135 [==============================] - 6s 41ms/step - loss: 0.0036 - val_loss: 0.0070
# Epoch 30/60
# 135/135 [==============================] - 4s 30ms/step - loss: 0.0036 - val_loss: 0.0064
# Epoch 31/60
# 135/135 [==============================] - 4s 30ms/step - loss: 0.0035 - val_loss: 0.0062
# Epoch 32/60
# 135/135 [==============================] - 5s 41ms/step - loss: 0.0035 - val_loss: 0.0062
# Epoch 33/60
# 135/135 [==============================] - 4s 30ms/step - loss: 0.0034 - val_loss: 0.0068
# Epoch 34/60
# 135/135 [==============================] - 4s 30ms/step - loss: 0.0034 - val_loss: 0.0061
# Epoch 35/60
# 135/135 [==============================] - 5s 40ms/step - loss: 0.0034 - val_loss: 0.0070
# Epoch 36/60
# 135/135 [==============================] - 4s 30ms/step - loss: 0.0034 - val_loss: 0.0060
# Epoch 37/60
# 135/135 [==============================] - 4s 30ms/step - loss: 0.0033 - val_loss: 0.0057
# Epoch 38/60
# 135/135 [==============================] - 5s 41ms/step - loss: 0.0033 - val_loss: 0.0069
# Epoch 39/60
# 135/135 [==============================] - 4s 30ms/step - loss: 0.0033 - val_loss: 0.0066
# Epoch 40/60
# 135/135 [==============================] - 4s 30ms/step - loss: 0.0032 - val_loss: 0.0057
# Epoch 41/60
# 135/135 [==============================] - 5s 39ms/step - loss: 0.0032 - val_loss: 0.0062
# Epoch 42/60
# 135/135 [==============================] - 4s 30ms/step - loss: 0.0032 - val_loss: 0.0062
# Epoch 43/60
# 135/135 [==============================] - 4s 30ms/step - loss: 0.0031 - val_loss: 0.0055
# Epoch 44/60
# 135/135 [==============================] - 5s 40ms/step - loss: 0.0031 - val_loss: 0.0055
# Epoch 45/60
# 135/135 [==============================] - 4s 31ms/step - loss: 0.0031 - val_loss: 0.0056
# Epoch 46/60
# 135/135 [==============================] - 4s 30ms/step - loss: 0.0030 - val_loss: 0.0055
# Epoch 47/60
# 135/135 [==============================] - 5s 39ms/step - loss: 0.0031 - val_loss: 0.0055
# Epoch 48/60
# 135/135 [==============================] - 4s 30ms/step - loss: 0.0030 - val_loss: 0.0057
# Epoch 49/60
# 135/135 [==============================] - 4s 30ms/step - loss: 0.0030 - val_loss: 0.0054
# Epoch 50/60
# 135/135 [==============================] - 5s 40ms/step - loss: 0.0030 - val_loss: 0.0059
# Epoch 51/60
# 135/135 [==============================] - 4s 30ms/step - loss: 0.0030 - val_loss: 0.0056
# Epoch 52/60
# 135/135 [==============================] - 4s 30ms/step - loss: 0.0030 - val_loss: 0.0054
# Epoch 53/60
# 135/135 [==============================] - 5s 39ms/step - loss: 0.0030 - val_loss: 0.0056
# Epoch 54/60
# 135/135 [==============================] - 4s 30ms/step - loss: 0.0030 - val_loss: 0.0054
# Epoch 55/60
# 135/135 [==============================] - 4s 30ms/step - loss: 0.0029 - val_loss: 0.0058
# Epoch 56/60
# 135/135 [==============================] - 5s 40ms/step - loss: 0.0029 - val_loss: 0.0056
# Epoch 57/60
# 135/135 [==============================] - 4s 30ms/step - loss: 0.0029 - val_loss: 0.0059
# Epoch 58/60
# 135/135 [==============================] - 4s 30ms/step - loss: 0.0028 - val_loss: 0.0052
# Epoch 59/60
# 135/135 [==============================] - 5s 40ms/step - loss: 0.0028 - val_loss: 0.0052
# Epoch 60/60
# 135/135 [==============================] - 4s 30ms/step - loss: 0.0028 - val_loss: 0.0050

# %%
# Mendapatkan nilai akhir dari training loss dan validation loss
final_training_loss = history.history['loss'][-1]
final_validation_loss = history.history['val_loss'][-1]

# %%
# Menampilkan hasil evaluasi
print(f'Final Training Loss: {final_training_loss:.4f}')
print(f'Final Validation Loss: {final_validation_loss:.4f}')
# Out:
# Final Training Loss: 0.0028
# Final Validation Loss: 0.0050

# %%
# Plot loss dan validation loss selama pelatihan
plt.figure(figsize=(14, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss') 
plt.show()

# %%
# Memprediksi data testing
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(predictions)
# Out:
# 15/15 [==============================] - 1s 8ms/step

# %%
# Menghitung metrik evaluasi
y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))

# %%
# Menghitung metrik evaluasi
mse = mean_squared_error(y_test_actual, predictions)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test_actual, predictions)
r2 = r2_score(y_test_actual, predictions)

# %%
# Tampilkan metrik evaluasi
print(f'MSE: {mse}')
print(f'RMSE: {rmse}')
print(f'MAE: {mae}')
print(f'R²: {r2}')
# Out:
# MSE: 14.679467150590549
# RMSE: 3.8313792752206806
# MAE: 2.4010753820756037
# R²: 0.9016142333084376

# %%
# Plot hasil prediksi dan data asli untuk data testing
plt.figure(figsize=(14, 5))
plt.plot(test_data['Date'], test_data['chla'], label='Testing Data (Actual)')
plt.plot(test_data['Date'][seq_length:], predictions, label='Testing Data (Predicted)', color='red')
plt.legend()
plt.xlabel('Date')
plt.ylabel('chla')
plt.title('Actual vs Predicted Cell Count (Testing Data)')
plt.show()
